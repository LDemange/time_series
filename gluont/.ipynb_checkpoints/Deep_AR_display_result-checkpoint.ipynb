# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import RobustScaler, OneHotEncoder, OrdinalEncoder
from sklearn.linear_model import Ridge, Lasso, LinearRegression
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.compose import ColumnTransformer, make_column_transformer, make_column_selector
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import cross_validate
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import cross_val_score
from tensorflow.keras import Sequential, layers
import matplotlib.pyplot as plt
pd.set_option("display.max_columns", False)
from sklearn.metrics import mean_absolute_percentage_error
from datetime import date, timedelta, datetime
from sklearn.metrics import r2_score
from tensorflow.keras.optimizers import Adam
######################################################
from gluonts.dataset.util import to_pandas
from gluonts.dataset.pandas import PandasDataset
from gluonts.dataset.repository.datasets import get_dataset
from gluonts.model.deepar import DeepAREstimator
from gluonts.mx import Trainer
from gluonts.evaluation import make_evaluation_predictions
import matplotlib.pyplot as plt

# %% [markdown]
# # Prepare dataset

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv('../data/data_preparation.csv', index_col=[0])
df=df.iloc[:-60]

# %% [markdown]
# ## Fill missing data

# %%
def replace_val(df,date1,date2): #on remplace les NaN dans l intervalle de date
    for col in df.columns:
        imputer = KNNImputer(n_neighbors=7) # Instantiate a SimpleImputer object with your strategy of choice
        imputer.fit(df[[col]]) # Call the "fit" method on the object
        df[col] = imputer.transform(df[[col]]) # Call the "transform" method on the object

# %%
df['Date']=pd.to_datetime(df['Date'], errors='coerce')
df = df.set_index('Date').asfreq('D')
replace_val(df,'2022-04-30','2022-05-06')

# %% [markdown]
# ### Select relevant features

# %%
df.drop(columns=['t - 1', 't - 2', 't - 3', 't - 4', 't - 5',
       't - 6', 't - 7', 't - 8', 't - 9', 't - 10', 't - 11', 't - 12',
       't - 13', 't - 14', 't - 15', 't - 16', 't - 17', 't - 18', 't - 19',
       't - 20', 't - 21', 't - 22', 't - 23', 't - 24', 't - 25', 't - 26',
       't - 27', 't - 28', 't - 29', 't - 30','sin365_1', 'cos365_1', 'sin365_2', 'cos365_2',
       'sin365_3', 'cos365_3','bank_holiday', 'school_holidays',
       'season','Thermique (MW)', 'Nucléaire (MW)', 'Eolien (MW)', 'Solaire (MW)',
       'Hydraulique (MW)', 'Pompage (MW)', 'Bioénergies (MW)',
       'Ech. physiques (MW)', 'Stockage batterie', 'Déstockage batterie',
       'Eolien terrestre', 'Eolien offshore', 'TCO Thermique (%)',
       'TCH Thermique (%)', 'TCO Nucléaire (%)', 'TCH Nucléaire (%)',
       'TCO Eolien (%)', 'TCH Eolien (%)', 'TCO Solaire (%)',
       'TCH Solaire (%)', 'Column 30','Code INSEE région','sin_month', 'cos_month',
        'num_day',
        'YEAR', 'MONTH', 'DAY',
        'T2MDEW', 'T2MWET', 'TS', 'T2M_RANGE',
       'T2M_MAX', 'T2M_MIN','PS', 'QV2M','WS10M','WS50M','RH2M','week_day' #temoin
        #'PRECTOTCORR' # PRECTOTCORR is bias-corrected total precipitation
        #'sin_day','cos_day'
                ],inplace=True)

# %%
df['id']='A'

# %%
df
# Out:
#             Consommation (MW)   T2M  PRECTOTCORR   sin_day   cos_day id
# Date
# 2013-02-02           262321.0  5.55         1.94 -0.974928 -0.222521  A
# 2013-02-03           273743.0  2.96         0.02 -0.781831  0.623490  A
# 2013-02-04           295369.0  4.67         0.00  0.000000  1.000000  A
# 2013-02-05           287424.0  6.65         0.19  0.781831  0.623490  A
# 2013-02-06           294084.0  2.71         0.10  0.974928 -0.222521  A
# ...                       ...   ...          ...       ...       ... ..
# 2022-03-07           273204.0  5.98         0.36  0.000000  1.000000  A
# 2022-03-08           280638.0  5.10         0.83  0.781831  0.623490  A
# 2022-03-09           270148.0  6.59         0.11  0.974928 -0.222521  A
# 2022-03-10           269684.0  7.48         0.64  0.433884 -0.900969  A
# 2022-03-11           264874.0  9.23         1.26 -0.433884 -0.900969  A
#
# [3325 rows x 6 columns]

# %%
nb_data_train = int(len(df)*0.85)
nb_data_val = int(len(df)*0.15)

# %%
N_test = 14 #on prédit les 14 derniers jours dans chaque dataframe

# %%
df_train=df.iloc[:nb_data_train]

# %%
df_val = df[nb_data_train:nb_data_train+nb_data_val]

# %%
df_train
# Out:
#             Consommation (MW)    T2M  PRECTOTCORR   sin_day   cos_day id
# Date
# 2013-02-02           262321.0   5.55         1.94 -0.974928 -0.222521  A
# 2013-02-03           273743.0   2.96         0.02 -0.781831  0.623490  A
# 2013-02-04           295369.0   4.67         0.00  0.000000  1.000000  A
# 2013-02-05           287424.0   6.65         0.19  0.781831  0.623490  A
# 2013-02-06           294084.0   2.71         0.10  0.974928 -0.222521  A
# ...                       ...    ...          ...       ...       ... ..
# 2020-10-24           193881.0  13.54         0.21 -0.974928 -0.222521  A
# 2020-10-25           193856.0  14.27         0.31 -0.781831  0.623490  A
# 2020-10-26           209799.0  12.45         3.84  0.000000  1.000000  A
# 2020-10-27           217222.0   9.68         0.02  0.781831  0.623490  A
# 2020-10-28           214524.0  12.33         0.07  0.974928 -0.222521  A
#
# [2826 rows x 6 columns]

# %%
df_val
# Out:
#             Consommation (MW)    T2M  PRECTOTCORR   sin_day   cos_day id
# Date
# 2020-10-29           209515.0  13.01         0.07  0.433884 -0.900969  A
# 2020-10-30           205857.0  14.46         0.00 -0.433884 -0.900969  A
# 2020-10-31           197481.0  13.38         0.10 -0.974928 -0.222521  A
# 2020-11-01           194049.0  12.63         0.06 -0.781831  0.623490  A
# 2020-11-02           206305.0  14.18         0.11  0.000000  1.000000  A
# ...                       ...    ...          ...       ...       ... ..
# 2022-03-06           261730.0   5.27         1.41 -0.781831  0.623490  A
# 2022-03-07           273204.0   5.98         0.36  0.000000  1.000000  A
# 2022-03-08           280638.0   5.10         0.83  0.781831  0.623490  A
# 2022-03-09           270148.0   6.59         0.11  0.974928 -0.222521  A
# 2022-03-10           269684.0   7.48         0.64  0.433884 -0.900969  A
#
# [498 rows x 6 columns]

# %%
#df=df.copy()
#df['Consommation (MW)'].iloc[-N_test:]=0 ###Commenter cette ligne pour preuve du bon fonctionnement

# %%
exo_feature = ['T2M','PRECTOTCORR', 'sin_day', 'cos_day']

# %%
ds_train = PandasDataset(df_train, target="Consommation (MW)",feat_dynamic_real=exo_feature)
ds_val = PandasDataset(df_val, target="Consommation (MW)",feat_dynamic_real=exo_feature)

# %%
estimator = DeepAREstimator(
    freq=ds_train.freq, prediction_length=N_test, trainer=Trainer(epochs=30,learning_rate=0.0001),
    use_feat_dynamic_real=True,
    batch_size=16,
    num_layers=2,
    num_cells=110
)

predictor = estimator.train(ds_train,ds_val)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.40it/s, epoch=1/30, avg_epoch_loss=12.7]
# 1it [00:00, 30.58it/s, epoch=1/30, validation_avg_epoch_loss=11.5]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 14.61it/s, epoch=2/30, avg_epoch_loss=11.3]
# 1it [00:00, 30.83it/s, epoch=2/30, validation_avg_epoch_loss=11]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.79it/s, epoch=3/30, avg_epoch_loss=11]
# 1it [00:00, 28.63it/s, epoch=3/30, validation_avg_epoch_loss=10.8]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.12it/s, epoch=4/30, avg_epoch_loss=10.9]
# 1it [00:00, 31.19it/s, epoch=4/30, validation_avg_epoch_loss=10.9]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 12.74it/s, epoch=5/30, avg_epoch_loss=10.8]
# 1it [00:00, 32.58it/s, epoch=5/30, validation_avg_epoch_loss=10.6]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.23it/s, epoch=6/30, avg_epoch_loss=10.7]
# 1it [00:00, 30.75it/s, epoch=6/30, validation_avg_epoch_loss=10.7]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.24it/s, epoch=7/30, avg_epoch_loss=10.7]
# 1it [00:00, 35.12it/s, epoch=7/30, validation_avg_epoch_loss=10.7]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:03<00:00, 13.20it/s, epoch=8/30, avg_epoch_loss=10.6]
# 1it [00:00, 30.32it/s, epoch=8/30, validation_avg_epoch_loss=10.7]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.91it/s, epoch=9/30, avg_epoch_loss=10.6]
# 1it [00:00, 20.74it/s, epoch=9/30, validation_avg_epoch_loss=10.7]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:05<00:00,  9.47it/s, epoch=10/30, avg_epoch_loss=10.5]
# 1it [00:00, 25.94it/s, epoch=10/30, validation_avg_epoch_loss=10.6]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 10.66it/s, epoch=11/30, avg_epoch_loss=10.5]
# 1it [00:00, 26.54it/s, epoch=11/30, validation_avg_epoch_loss=10.5]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 10.42it/s, epoch=12/30, avg_epoch_loss=10.5]
# 1it [00:00, 29.32it/s, epoch=12/30, validation_avg_epoch_loss=10.5]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.05it/s, epoch=13/30, avg_epoch_loss=10.5]
# 1it [00:00, 32.51it/s, epoch=13/30, validation_avg_epoch_loss=10.5]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.82it/s, epoch=14/30, avg_epoch_loss=10.5]
# 1it [00:00, 29.82it/s, epoch=14/30, validation_avg_epoch_loss=10.5]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.95it/s, epoch=15/30, avg_epoch_loss=10.4]
# 1it [00:00, 30.30it/s, epoch=15/30, validation_avg_epoch_loss=10.4]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.65it/s, epoch=16/30, avg_epoch_loss=10.4]
# 1it [00:00, 32.08it/s, epoch=16/30, validation_avg_epoch_loss=10.8]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 12.43it/s, epoch=17/30, avg_epoch_loss=10.4]
# 1it [00:00, 29.79it/s, epoch=17/30, validation_avg_epoch_loss=10.5]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.92it/s, epoch=18/30, avg_epoch_loss=10.4]
# 1it [00:00, 29.60it/s, epoch=18/30, validation_avg_epoch_loss=10.5]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.42it/s, epoch=19/30, avg_epoch_loss=10.4]
# 1it [00:00, 29.82it/s, epoch=19/30, validation_avg_epoch_loss=10.4]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.73it/s, epoch=20/30, avg_epoch_loss=10.4]
# 1it [00:00, 31.31it/s, epoch=20/30, validation_avg_epoch_loss=10.4]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.30it/s, epoch=21/30, avg_epoch_loss=10.3]
# 1it [00:00, 29.19it/s, epoch=21/30, validation_avg_epoch_loss=10.4]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.98it/s, epoch=22/30, avg_epoch_loss=10.4]
# 1it [00:00, 29.34it/s, epoch=22/30, validation_avg_epoch_loss=10.5]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.84it/s, epoch=23/30, avg_epoch_loss=10.3]
# 1it [00:00, 27.59it/s, epoch=23/30, validation_avg_epoch_loss=10.5]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 10.77it/s, epoch=24/30, avg_epoch_loss=10.3]
# 1it [00:00, 27.11it/s, epoch=24/30, validation_avg_epoch_loss=10.3]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.27it/s, epoch=25/30, avg_epoch_loss=10.3]
# 1it [00:00, 23.71it/s, epoch=25/30, validation_avg_epoch_loss=10.4]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 10.85it/s, epoch=26/30, avg_epoch_loss=10.3]
# 1it [00:00, 26.71it/s, epoch=26/30, validation_avg_epoch_loss=10.3]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 10.72it/s, epoch=27/30, avg_epoch_loss=10.3]
# 1it [00:00, 28.22it/s, epoch=27/30, validation_avg_epoch_loss=10.3]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.05it/s, epoch=28/30, avg_epoch_loss=10.3]
# 1it [00:00, 28.38it/s, epoch=28/30, validation_avg_epoch_loss=10.3]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.52it/s, epoch=29/30, avg_epoch_loss=10.3]
# 1it [00:00, 29.47it/s, epoch=29/30, validation_avg_epoch_loss=10.6]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:04<00:00, 11.52it/s, epoch=30/30, avg_epoch_loss=10.3]
# 1it [00:00, 30.53it/s, epoch=30/30, validation_avg_epoch_loss=10.5]

# %%
reduction=100
ds = PandasDataset(df.iloc[:-reduction], target="Consommation (MW)",feat_dynamic_real=exo_feature)

# %%
forecast_it, ts_it = make_evaluation_predictions(
    dataset=ds,#dataset.test,  # test dataset
    predictor=predictor,  # predictor, réglé pour predire les N_test derniers jours du dataframe
    num_samples=100,  # number of sample paths we want for evaluation, is useful for confidence interval
)

# %%
forecasts = list(forecast_it)
tss = list(ts_it)

# %%
# first entry of the time series list
ts_entry = tss[0]

#np.array(ts_entry[:5]).reshape(-1,) #Get first values

# %%
forecast_entry = forecasts[0]

# %%
plot_length = N_test
prediction_intervals = (50.0, 90.0)
legend = ["observations", "median prediction"] + [f"{k}% prediction interval" for k in prediction_intervals][::-1] + ['true_value']
fig, ax = plt.subplots(1, 1, figsize=(10, 7))

forecast_entry.plot(prediction_intervals=prediction_intervals, color="g",label='prediction')
plt.plot(df['Consommation (MW)'],label='Training',color='blue')
plt.plot(ts_entry[-plot_length:],label='True value',color='red')
plt.legend(loc="upper left")
plt.xlim(left=df['Consommation (MW)'].index[-reduction-50])
#plt.xlim(left=ts_entry[-plot_length:].index[0])
plt.show()

# %%
y_baseline = np.ones(N_test)*df['Consommation (MW)'].iloc[-reduction-N_test-1]
y_true = df['Consommation (MW)'].iloc[-reduction-N_test:-reduction]
y_pred = forecasts[0].median

# %%
print(f'mape(y_pred) = {mean_absolute_percentage_error(y_true, y_pred)}')
print(f'mape(y_baseline) = {mean_absolute_percentage_error(y_true, y_baseline)}')
# Out:
# mape(y_pred) = 0.02539235637828984
# mape(y_baseline) = 0.08047050793053122
